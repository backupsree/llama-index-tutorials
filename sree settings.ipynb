# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv(dotenv_path=".env", verbose=True, override=True)
print(f"GOOGLE_API_KEY: {os.getenv('GOOGLE_API_KEY')}")
# Out:
# GOOGLE_API_KEY: None

# %%
from llama_index.llms.openai import OpenAI

# %%
from llama_index.llms.google_genai import GoogleGenAI

llm = GoogleGenAI(model="gemini-2.5-pro")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 from llama_index.llms.google_genai import GoogleGenAI
# ----> 3 llm = GoogleGenAI(model="gemini-2.5-pro")
#
# File c:\Users\SRINATH\venvs\venv_lamaindex\Lib\site-packages\llama_index\llms\google_genai\base.py:207, in GoogleGenAI.__init__(self, model, api_key, temperature, max_tokens, context_window, max_retries, vertexai_config, http_options, debug_config, generation_config, callback_manager, is_function_calling_model, cached_content, built_in_tool, file_mode, **kwargs)
#     204 if debug_config:
#     205     config_params["debug_config"] = debug_config
# --> 207 client = google.genai.Client(**config_params)
#     208 model_meta = client.models.get(model=model)
#     210 super().__init__(
#     211     model=model,
#     212     temperature=temperature,
#    (...)    220     **kwargs,
#     221 )
#
# File c:\Users\SRINATH\venvs\venv_lamaindex\Lib\site-packages\google\genai\client.py:396, in Client.__init__(self, vertexai, api_key, credentials, project, location, debug_config, http_options)
#     393   else:
#     394     http_options = HttpOptions(base_url=base_url)
# --> 396 self._api_client = self._get_api_client(
#     397     vertexai=vertexai,
#     398     api_key=api_key,
#     399     credentials=credentials,
#     400     project=project,
#     401     location=location,
#     402     debug_config=self._debug_config,
#     403     http_options=http_options,
#     404 )
#     406 self._aio = AsyncClient(self._api_client)
#     407 self._models = Models(self._api_client)
#
# File c:\Users\SRINATH\venvs\venv_lamaindex\Lib\site-packages\google\genai\client.py:444, in Client._get_api_client(vertexai, api_key, credentials, project, location, debug_config, http_options)
#     427 if debug_config and debug_config.client_mode in [
#     428     'record',
#     429     'replay',
#     430     'auto',
#     431 ]:
#     432   return ReplayApiClient(
#     433       mode=debug_config.client_mode,  # type: ignore[arg-type]
#     434       replay_id=debug_config.replay_id,  # type: ignore[arg-type]
#    (...)    441       http_options=http_options,
#     442   )
# --> 444 return BaseApiClient(
#     445     vertexai=vertexai,
#     446     api_key=api_key,
#     447     credentials=credentials,
#     448     project=project,
#     449     location=location,
#     450     http_options=http_options,
#     451 )
#
# File c:\Users\SRINATH\venvs\venv_lamaindex\Lib\site-packages\google\genai\_api_client.py:683, in BaseApiClient.__init__(self, vertexai, api_key, credentials, project, location, http_options)
#     681 else:  # Implicit initialization or missing arguments.
#     682   if not self.api_key:
# --> 683     raise ValueError(
#     684         'Missing key inputs argument! To use the Google AI API,'
#     685         ' provide (`api_key`) arguments. To use the Google Cloud API,'
#     686         ' provide (`vertexai`, `project` & `location`) arguments.'
#     687     )
#     688   self._http_options.base_url = 'https://generativelanguage.googleapis.com/'
#     689   self._http_options.api_version = 'v1beta'
#
# ValueError: Missing key inputs argument! To use the Google AI API, provide (`api_key`) arguments. To use the Google Cloud API, provide (`vertexai`, `project` & `location`) arguments.
